# %% [markdown]
# <a href="https://colab.research.google.com/github/advapplab/esgBERT_hf/blob/main/GLUE_QQP_evaluate_Finetune.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch datasets evaluate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 34.2 MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (1.13.0+cu116)
# Collecting datasets
#   Downloading datasets-2.8.0-py3-none-any.whl (452 kB)
#      |████████████████████████████████| 452 kB 72.3 MB/s
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 5.7 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.8.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 66.9 MB/s
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 58.5 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: dill<0.3.7 in /usr/local/lib/python3.8/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from datasets) (1.3.5)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
#      |████████████████████████████████| 213 kB 76.6 MB/s
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py38-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 57.7 MB/s
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from datasets) (3.8.3)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (2022.11.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (6.0.3)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.12.7)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 59.0 MB/s
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: urllib3, xxhash, responses, multiprocess, huggingface-hub, tokenizers, datasets, transformers, evaluate
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed datasets-2.8.0 evaluate-0.4.0 huggingface-hub-0.11.1 multiprocess-0.70.14 responses-0.18.0 tokenizers-0.13.2 transformers-4.25.1 urllib3-1.25.11 xxhash-3.2.0

# %%
from datasets import load_metric
from datasets import load_dataset
# dataset_mnli = load_dataset('glue', 'mnli') # , 'mnli', 'qqp', 'cola', 'sst2'
dataset_qqp = load_dataset('glue', 'qqp')
# dataset_cola = load_dataset('glue', 'cola')
# dataset_sst2 = load_dataset('glue', 'sst2')

# metric_mnli = load_metric('glue', 'mnli') # , num_process=num_process, process_id=process_id, experiment_id="My_experiment_10"
# metric_qqp = load_metric('glue', 'qqp')
# metric_cola = load_metric('glue', 'cola')
# metric_sst2 = load_metric('glue', 'sst2')
# Out:
# Downloading builder script:   0%|          | 0.00/28.8k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/28.7k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/27.8k [00:00<?, ?B/s]
# Downloading and preparing dataset glue/qqp to /root/.cache/huggingface/datasets/glue/qqp/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad...
# Downloading data:   0%|          | 0.00/41.7M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/363846 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/40430 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/390965 [00:00<?, ? examples/s]
# Dataset glue downloaded and prepared to /root/.cache/huggingface/datasets/glue/qqp/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
import torch
from transformers import BertTokenizer, BertForSequenceClassification

tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model = BertForSequenceClassification.from_pretrained("bert-base-uncased", num_labels=2)
# Out:
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# inputs = tokenizer("Hello, my dog is cute", return_tensors="pt")

# with torch.no_grad():
#     logits = model(**inputs).logits

# predicted_class_id = logits.argmax().item()
# model.config.id2label[predicted_class_id]

# %%
dataset_qqp
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['question1', 'question2', 'label', 'idx'],
#         num_rows: 363846
#     })
#     validation: Dataset({
#         features: ['question1', 'question2', 'label', 'idx'],
#         num_rows: 40430
#     })
#     test: Dataset({
#         features: ['question1', 'question2', 'label', 'idx'],
#         num_rows: 390965
#     })
# })

# %%
def tokenize_function(examples):
    return tokenizer(examples["question1"], examples["question2"], padding="max_length", truncation=True, max_length=128)

tokenized_datasets = dataset_qqp.map(tokenize_function, batched=True)
# Out:
#   0%|          | 0/364 [00:00<?, ?ba/s]
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
#   0%|          | 0/41 [00:00<?, ?ba/s]
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
#   0%|          | 0/391 [00:00<?, ?ba/s]
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.

# %%
tokenized_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['question1', 'question2', 'label', 'idx', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 363846
#     })
#     validation: Dataset({
#         features: ['question1', 'question2', 'label', 'idx', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 40430
#     })
#     test: Dataset({
#         features: ['question1', 'question2', 'label', 'idx', 'input_ids', 'token_type_ids', 'attention_mask'],
#         num_rows: 390965
#     })
# })

# %%
# tokenized_datasets.set_format(type="torch", columns=["input_ids", "token_type_ids", "attention_mask"])
# tokenized_dataset_mnli.format['type']

# %%
# with torch.no_grad():
#     logits = model(**tokenized_dataset_mnli).logits

# predicted_class_id = logits.argmax().item()
# model.config.id2label[predicted_class_id]

# %%
eval_dataset_qqp = tokenized_datasets['validation'] # .shuffle(seed=42).select(range(256))
eval_dataset_qqp
# Out:
# Dataset({
#     features: ['question1', 'question2', 'label', 'idx', 'input_ids', 'token_type_ids', 'attention_mask'],
#     num_rows: 40430
# })

# %%
train_dataset_qqp = tokenized_datasets['train'] # .shuffle(seed=42).select(range(256))
train_dataset_qqp
# Out:
# Dataset({
#     features: ['question1', 'question2', 'label', 'idx', 'input_ids', 'token_type_ids', 'attention_mask'],
#     num_rows: 363846
# })

# %%
import numpy as np
import evaluate

metric = evaluate.load('glue', 'qqp')

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    print(logits[0], labels[0])
    return metric.compute(predictions=predictions, references=labels)
# Out:
# Downloading builder script:   0%|          | 0.00/5.75k [00:00<?, ?B/s]

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(output_dir='/content/',save_total_limit = 1)

# %%
from transformers import Trainer

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    eval_dataset=eval_dataset_qqp,
    compute_metrics=compute_metrics
)
trainer.evaluate()
# Out:
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: idx, question2, question1. If idx, question2, question1 are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 40430
#   Batch size = 8
#     <div>
#
#       <progress value='5054' max='5054' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5054/5054 04:51]
#     </div>
# [-0.07103623  0.725224  ] 0
# {'eval_loss': 0.8484100699424744,
#  'eval_accuracy': 0.3798417017066535,
#  'eval_f1': 0.5428222380249075,
#  'eval_runtime': 294.6802,
#  'eval_samples_per_second': 137.2,
#  'eval_steps_per_second': 17.151}

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset_qqp,
    eval_dataset=eval_dataset_qqp,
    compute_metrics=compute_metrics
)
trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: idx, question2, question1. If idx, question2, question1 are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.8/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 363846
#   Num Epochs = 3
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 136443
#   Number of trainable parameters = 109483778
#     <div>
#
#       <progress value='32132' max='136443' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 32132/136443 1:53:45 < 6:09:18, 4.71 it/s, Epoch 0.71/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.530000</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.470300</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.457500</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.450500</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.417200</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.428400</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.433200</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.395200</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.404700</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.400300</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.397400</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.420500</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.404000</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.399200</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.404100</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.405300</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.411000</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.411100</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.403900</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.401300</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.418100</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.403300</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.403400</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.410300</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.390700</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.429600</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.454000</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.433100</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>0.439600</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.432300</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>0.423900</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.425000</td>
#     </tr>
#     <tr>
#       <td>16500</td>
#       <td>0.478400</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.520100</td>
#     </tr>
#     <tr>
#       <td>17500</td>
#       <td>0.593400</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.492600</td>
#     </tr>
#     <tr>
#       <td>18500</td>
#       <td>0.515700</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>0.501800</td>
#     </tr>
#     <tr>
#       <td>19500</td>
#       <td>0.509300</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.525800</td>
#     </tr>
#     <tr>
#       <td>20500</td>
#       <td>0.542200</td>
#     </tr>
#     <tr>
#       <td>21000</td>
#       <td>0.549400</td>
#     </tr>
#     <tr>
#       <td>21500</td>
#       <td>0.541200</td>
#     </tr>
#     <tr>
#       <td>22000</td>
#       <td>0.532800</td>
#     </tr>
#     <tr>
#       <td>22500</td>
#       <td>0.552500</td>
#     </tr>
#     <tr>
#       <td>23000</td>
#       <td>0.566300</td>
#     </tr>
#     <tr>
#       <td>23500</td>
#       <td>0.598700</td>
#     </tr>
#     <tr>
#       <td>24000</td>
#       <td>0.624700</td>
#     </tr>
#     <tr>
#       <td>24500</td>
#       <td>0.628300</td>
#     </tr>
#     <tr>
#       <td>25000</td>
#       <td>0.649800</td>
#     </tr>
#     <tr>
#       <td>25500</td>
#       <td>0.650700</td>
#     </tr>
#     <tr>
#       <td>26000</td>
#       <td>0.649400</td>
#     </tr>
#     <tr>
#       <td>26500</td>
#       <td>0.646000</td>
#     </tr>
#     <tr>
#       <td>27000</td>
#       <td>0.636300</td>
#     </tr>
#     <tr>
#       <td>27500</td>
#       <td>0.648300</td>
#     </tr>
#     <tr>
#       <td>28000</td>
#       <td>0.652600</td>
#     </tr>
#     <tr>
#       <td>28500</td>
#       <td>0.655100</td>
#     </tr>
#     <tr>
#       <td>29000</td>
#       <td>0.659100</td>
#     </tr>
#     <tr>
#       <td>29500</td>
#       <td>0.651600</td>
#     </tr>
#     <tr>
#       <td>30000</td>
#       <td>0.658800</td>
#     </tr>
#     <tr>
#       <td>30500</td>
#       <td>0.662200</td>
#     </tr>
#     <tr>
#       <td>31000</td>
#       <td>0.658300</td>
#     </tr>
#     <tr>
#       <td>31500</td>
#       <td>0.665300</td>
#     </tr>
#     <tr>
#       <td>32000</td>
#       <td>0.663200</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to /content/checkpoint-500
# Configuration saved in /content/checkpoint-500/config.json
# Model weights saved in /content/checkpoint-500/pytorch_model.bin
# Saving model checkpoint to /content/checkpoint-1000
# Configuration saved in /content/checkpoint-1000/config.json
# Model weights saved in /content/checkpoint-1000/pytorch_model.bin
# Saving model checkpoint to /content/checkpoint-1500
# Configuration saved in /content/checkpoint-1500/config.json
# Model weights saved in /content/checkpoint-1500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-2000
# Configuration saved in /content/checkpoint-2000/config.json
# Model weights saved in /content/checkpoint-2000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-1000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-2500
# Configuration saved in /content/checkpoint-2500/config.json
# Model weights saved in /content/checkpoint-2500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-1500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-3000
# Configuration saved in /content/checkpoint-3000/config.json
# Model weights saved in /content/checkpoint-3000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-2000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-3500
# Configuration saved in /content/checkpoint-3500/config.json
# Model weights saved in /content/checkpoint-3500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-2500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-4000
# Configuration saved in /content/checkpoint-4000/config.json
# Model weights saved in /content/checkpoint-4000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-3000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-4500
# Configuration saved in /content/checkpoint-4500/config.json
# Model weights saved in /content/checkpoint-4500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-3500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-5000
# Configuration saved in /content/checkpoint-5000/config.json
# Model weights saved in /content/checkpoint-5000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-4000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-5500
# Configuration saved in /content/checkpoint-5500/config.json
# Model weights saved in /content/checkpoint-5500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-4500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-6000
# Configuration saved in /content/checkpoint-6000/config.json
# Model weights saved in /content/checkpoint-6000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-5000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-6500
# Configuration saved in /content/checkpoint-6500/config.json
# Model weights saved in /content/checkpoint-6500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-5500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-7000
# Configuration saved in /content/checkpoint-7000/config.json
# Model weights saved in /content/checkpoint-7000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-6000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-7500
# Configuration saved in /content/checkpoint-7500/config.json
# Model weights saved in /content/checkpoint-7500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-6500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-8000
# Configuration saved in /content/checkpoint-8000/config.json
# Model weights saved in /content/checkpoint-8000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-7000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-8500
# Configuration saved in /content/checkpoint-8500/config.json
# Model weights saved in /content/checkpoint-8500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-7500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-9000
# Configuration saved in /content/checkpoint-9000/config.json
# Model weights saved in /content/checkpoint-9000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-8000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-9500
# Configuration saved in /content/checkpoint-9500/config.json
# Model weights saved in /content/checkpoint-9500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-8500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-10000
# Configuration saved in /content/checkpoint-10000/config.json
# Model weights saved in /content/checkpoint-10000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-9000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-10500
# Configuration saved in /content/checkpoint-10500/config.json
# Model weights saved in /content/checkpoint-10500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-9500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-11000
# Configuration saved in /content/checkpoint-11000/config.json
# Model weights saved in /content/checkpoint-11000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-10000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-11500
# Configuration saved in /content/checkpoint-11500/config.json
# Model weights saved in /content/checkpoint-11500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-10500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-12000
# Configuration saved in /content/checkpoint-12000/config.json
# Model weights saved in /content/checkpoint-12000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-11000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-12500
# Configuration saved in /content/checkpoint-12500/config.json
# Model weights saved in /content/checkpoint-12500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-11500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-13000
# Configuration saved in /content/checkpoint-13000/config.json
# Model weights saved in /content/checkpoint-13000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-12000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-13500
# Configuration saved in /content/checkpoint-13500/config.json
# Model weights saved in /content/checkpoint-13500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-12500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-14000
# Configuration saved in /content/checkpoint-14000/config.json
# Model weights saved in /content/checkpoint-14000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-13000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-14500
# Configuration saved in /content/checkpoint-14500/config.json
# Model weights saved in /content/checkpoint-14500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-13500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-15000
# Configuration saved in /content/checkpoint-15000/config.json
# Model weights saved in /content/checkpoint-15000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-14000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-15500
# Configuration saved in /content/checkpoint-15500/config.json
# Model weights saved in /content/checkpoint-15500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-14500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-16000
# Configuration saved in /content/checkpoint-16000/config.json
# Model weights saved in /content/checkpoint-16000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-15000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-16500
# Configuration saved in /content/checkpoint-16500/config.json
# Model weights saved in /content/checkpoint-16500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-15500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-17000
# Configuration saved in /content/checkpoint-17000/config.json
# Model weights saved in /content/checkpoint-17000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-16000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-17500
# Configuration saved in /content/checkpoint-17500/config.json
# Model weights saved in /content/checkpoint-17500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-16500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-18000
# Configuration saved in /content/checkpoint-18000/config.json
# Model weights saved in /content/checkpoint-18000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-17000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-18500
# Configuration saved in /content/checkpoint-18500/config.json
# Model weights saved in /content/checkpoint-18500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-17500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-19000
# Configuration saved in /content/checkpoint-19000/config.json
# Model weights saved in /content/checkpoint-19000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-18000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-19500
# Configuration saved in /content/checkpoint-19500/config.json
# Model weights saved in /content/checkpoint-19500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-18500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-20000
# Configuration saved in /content/checkpoint-20000/config.json
# Model weights saved in /content/checkpoint-20000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-19000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-20500
# Configuration saved in /content/checkpoint-20500/config.json
# Model weights saved in /content/checkpoint-20500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-19500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-21000
# Configuration saved in /content/checkpoint-21000/config.json
# Model weights saved in /content/checkpoint-21000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-20000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-21500
# Configuration saved in /content/checkpoint-21500/config.json
# Model weights saved in /content/checkpoint-21500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-20500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-22000
# Configuration saved in /content/checkpoint-22000/config.json
# Model weights saved in /content/checkpoint-22000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-21000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-22500
# Configuration saved in /content/checkpoint-22500/config.json
# Model weights saved in /content/checkpoint-22500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-21500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-23000
# Configuration saved in /content/checkpoint-23000/config.json
# Model weights saved in /content/checkpoint-23000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-22000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-23500
# Configuration saved in /content/checkpoint-23500/config.json
# Model weights saved in /content/checkpoint-23500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-22500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-24000
# Configuration saved in /content/checkpoint-24000/config.json
# Model weights saved in /content/checkpoint-24000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-23000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-24500
# Configuration saved in /content/checkpoint-24500/config.json
# Model weights saved in /content/checkpoint-24500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-23500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-25000
# Configuration saved in /content/checkpoint-25000/config.json
# Model weights saved in /content/checkpoint-25000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-24000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-25500
# Configuration saved in /content/checkpoint-25500/config.json
# Model weights saved in /content/checkpoint-25500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-24500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-26000
# Configuration saved in /content/checkpoint-26000/config.json
# Model weights saved in /content/checkpoint-26000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-25000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-26500
# Configuration saved in /content/checkpoint-26500/config.json
# Model weights saved in /content/checkpoint-26500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-25500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-27000
# Configuration saved in /content/checkpoint-27000/config.json
# Model weights saved in /content/checkpoint-27000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-26000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-27500
# Configuration saved in /content/checkpoint-27500/config.json
# Model weights saved in /content/checkpoint-27500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-26500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-28000
# Configuration saved in /content/checkpoint-28000/config.json
# Model weights saved in /content/checkpoint-28000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-27000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-28500
# Configuration saved in /content/checkpoint-28500/config.json
# Model weights saved in /content/checkpoint-28500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-27500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-29000
# Configuration saved in /content/checkpoint-29000/config.json
# Model weights saved in /content/checkpoint-29000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-28000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-29500
# Configuration saved in /content/checkpoint-29500/config.json
# Model weights saved in /content/checkpoint-29500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-28500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-30000
# Configuration saved in /content/checkpoint-30000/config.json
# Model weights saved in /content/checkpoint-30000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-29000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-30500
# Configuration saved in /content/checkpoint-30500/config.json
# Model weights saved in /content/checkpoint-30500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-29500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-31000
# Configuration saved in /content/checkpoint-31000/config.json
# Model weights saved in /content/checkpoint-31000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-30000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-31500
# Configuration saved in /content/checkpoint-31500/config.json
# Model weights saved in /content/checkpoint-31500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-30500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-32000
# Configuration saved in /content/checkpoint-32000/config.json
# Model weights saved in /content/checkpoint-32000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-31000] due to args.save_total_limit
#     <div>
#
#       <progress value='60038' max='136443' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 60038/136443 3:32:18 < 4:30:12, 4.71 it/s, Epoch 1.32/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.530000</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.470300</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.457500</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.450500</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.417200</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.428400</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.433200</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.395200</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.404700</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.400300</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.397400</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.420500</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.404000</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.399200</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.404100</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.405300</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.411000</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.411100</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.403900</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.401300</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.418100</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.403300</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.403400</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.410300</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.390700</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.429600</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.454000</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.433100</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>0.439600</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.432300</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>0.423900</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.425000</td>
#     </tr>
#     <tr>
#       <td>16500</td>
#       <td>0.478400</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.520100</td>
#     </tr>
#     <tr>
#       <td>17500</td>
#       <td>0.593400</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.492600</td>
#     </tr>
#     <tr>
#       <td>18500</td>
#       <td>0.515700</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>0.501800</td>
#     </tr>
#     <tr>
#       <td>19500</td>
#       <td>0.509300</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.525800</td>
#     </tr>
#     <tr>
#       <td>20500</td>
#       <td>0.542200</td>
#     </tr>
#     <tr>
#       <td>21000</td>
#       <td>0.549400</td>
#     </tr>
#     <tr>
#       <td>21500</td>
#       <td>0.541200</td>
#     </tr>
#     <tr>
#       <td>22000</td>
#       <td>0.532800</td>
#     </tr>
#     <tr>
#       <td>22500</td>
#       <td>0.552500</td>
#     </tr>
#     <tr>
#       <td>23000</td>
#       <td>0.566300</td>
#     </tr>
#     <tr>
#       <td>23500</td>
#       <td>0.598700</td>
#     </tr>
#     <tr>
#       <td>24000</td>
#       <td>0.624700</td>
#     </tr>
#     <tr>
#       <td>24500</td>
#       <td>0.628300</td>
#     </tr>
#     <tr>
#       <td>25000</td>
#       <td>0.649800</td>
#     </tr>
#     <tr>
#       <td>25500</td>
#       <td>0.650700</td>
#     </tr>
#     <tr>
#       <td>26000</td>
#       <td>0.649400</td>
#     </tr>
#     <tr>
#       <td>26500</td>
#       <td>0.646000</td>
#     </tr>
#     <tr>
#       <td>27000</td>
#       <td>0.636300</td>
#     </tr>
#     <tr>
#       <td>27500</td>
#       <td>0.648300</td>
#     </tr>
#     <tr>
#       <td>28000</td>
#       <td>0.652600</td>
#     </tr>
#     <tr>
#       <td>28500</td>
#       <td>0.655100</td>
#     </tr>
#     <tr>
#       <td>29000</td>
#       <td>0.659100</td>
#     </tr>
#     <tr>
#       <td>29500</td>
#       <td>0.651600</td>
#     </tr>
#     <tr>
#       <td>30000</td>
#       <td>0.658800</td>
#     </tr>
#     <tr>
#       <td>30500</td>
#       <td>0.662200</td>
#     </tr>
#     <tr>
#       <td>31000</td>
#       <td>0.658300</td>
#     </tr>
#     <tr>
#       <td>31500</td>
#       <td>0.665300</td>
#     </tr>
#     <tr>
#       <td>32000</td>
#       <td>0.663200</td>
#     </tr>
#     <tr>
#       <td>32500</td>
#       <td>0.651300</td>
#     </tr>
#     <tr>
#       <td>33000</td>
#       <td>0.668500</td>
#     </tr>
#     <tr>
#       <td>33500</td>
#       <td>0.658500</td>
#     </tr>
#     <tr>
#       <td>34000</td>
#       <td>0.662700</td>
#     </tr>
#     <tr>
#       <td>34500</td>
#       <td>0.657300</td>
#     </tr>
#     <tr>
#       <td>35000</td>
#       <td>0.663300</td>
#     </tr>
#     <tr>
#       <td>35500</td>
#       <td>0.661600</td>
#     </tr>
#     <tr>
#       <td>36000</td>
#       <td>0.664200</td>
#     </tr>
#     <tr>
#       <td>36500</td>
#       <td>0.654300</td>
#     </tr>
#     <tr>
#       <td>37000</td>
#       <td>0.661000</td>
#     </tr>
#     <tr>
#       <td>37500</td>
#       <td>0.651300</td>
#     </tr>
#     <tr>
#       <td>38000</td>
#       <td>0.661300</td>
#     </tr>
#     <tr>
#       <td>38500</td>
#       <td>0.669900</td>
#     </tr>
#     <tr>
#       <td>39000</td>
#       <td>0.658300</td>
#     </tr>
#     <tr>
#       <td>39500</td>
#       <td>0.666200</td>
#     </tr>
#     <tr>
#       <td>40000</td>
#       <td>0.661800</td>
#     </tr>
#     <tr>
#       <td>40500</td>
#       <td>0.668600</td>
#     </tr>
#     <tr>
#       <td>41000</td>
#       <td>0.660800</td>
#     </tr>
#     <tr>
#       <td>41500</td>
#       <td>0.661000</td>
#     </tr>
#     <tr>
#       <td>42000</td>
#       <td>0.668000</td>
#     </tr>
#     <tr>
#       <td>42500</td>
#       <td>0.666000</td>
#     </tr>
#     <tr>
#       <td>43000</td>
#       <td>0.656200</td>
#     </tr>
#     <tr>
#       <td>43500</td>
#       <td>0.663800</td>
#     </tr>
#     <tr>
#       <td>44000</td>
#       <td>0.653700</td>
#     </tr>
#     <tr>
#       <td>44500</td>
#       <td>0.657500</td>
#     </tr>
#     <tr>
#       <td>45000</td>
#       <td>0.665200</td>
#     </tr>
#     <tr>
#       <td>45500</td>
#       <td>0.666300</td>
#     </tr>
#     <tr>
#       <td>46000</td>
#       <td>0.657100</td>
#     </tr>
#     <tr>
#       <td>46500</td>
#       <td>0.660100</td>
#     </tr>
#     <tr>
#       <td>47000</td>
#       <td>0.667000</td>
#     </tr>
#     <tr>
#       <td>47500</td>
#       <td>0.662000</td>
#     </tr>
#     <tr>
#       <td>48000</td>
#       <td>0.660600</td>
#     </tr>
#     <tr>
#       <td>48500</td>
#       <td>0.662100</td>
#     </tr>
#     <tr>
#       <td>49000</td>
#       <td>0.662900</td>
#     </tr>
#     <tr>
#       <td>49500</td>
#       <td>0.664600</td>
#     </tr>
#     <tr>
#       <td>50000</td>
#       <td>0.660200</td>
#     </tr>
#     <tr>
#       <td>50500</td>
#       <td>0.659800</td>
#     </tr>
#     <tr>
#       <td>51000</td>
#       <td>0.658100</td>
#     </tr>
#     <tr>
#       <td>51500</td>
#       <td>0.665800</td>
#     </tr>
#     <tr>
#       <td>52000</td>
#       <td>0.667400</td>
#     </tr>
#     <tr>
#       <td>52500</td>
#       <td>0.660000</td>
#     </tr>
#     <tr>
#       <td>53000</td>
#       <td>0.652600</td>
#     </tr>
#     <tr>
#       <td>53500</td>
#       <td>0.660300</td>
#     </tr>
#     <tr>
#       <td>54000</td>
#       <td>0.660000</td>
#     </tr>
#     <tr>
#       <td>54500</td>
#       <td>0.653200</td>
#     </tr>
#     <tr>
#       <td>55000</td>
#       <td>0.658600</td>
#     </tr>
#     <tr>
#       <td>55500</td>
#       <td>0.656800</td>
#     </tr>
#     <tr>
#       <td>56000</td>
#       <td>0.654600</td>
#     </tr>
#     <tr>
#       <td>56500</td>
#       <td>0.662000</td>
#     </tr>
#     <tr>
#       <td>57000</td>
#       <td>0.662300</td>
#     </tr>
#     <tr>
#       <td>57500</td>
#       <td>0.660800</td>
#     </tr>
#     <tr>
#       <td>58000</td>
#       <td>0.664400</td>
#     </tr>
#     <tr>
#       <td>58500</td>
#       <td>0.663000</td>
#     </tr>
#     <tr>
#       <td>59000</td>
#       <td>0.661200</td>
#     </tr>
#     <tr>
#       <td>59500</td>
#       <td>0.672400</td>
#     </tr>
#     <tr>
#       <td>60000</td>
# Saving model checkpoint to /content/checkpoint-32500
# Configuration saved in /content/checkpoint-32500/config.json
# Model weights saved in /content/checkpoint-32500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-31500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-33000
# Configuration saved in /content/checkpoint-33000/config.json
# Model weights saved in /content/checkpoint-33000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-32000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-33500
# Configuration saved in /content/checkpoint-33500/config.json
# Model weights saved in /content/checkpoint-33500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-32500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-34000
# Configuration saved in /content/checkpoint-34000/config.json
# Model weights saved in /content/checkpoint-34000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-33000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-34500
# Configuration saved in /content/checkpoint-34500/config.json
# Model weights saved in /content/checkpoint-34500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-33500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-35000
# Configuration saved in /content/checkpoint-35000/config.json
# Model weights saved in /content/checkpoint-35000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-34000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-35500
# Configuration saved in /content/checkpoint-35500/config.json
# Model weights saved in /content/checkpoint-35500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-34500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-36000
# Configuration saved in /content/checkpoint-36000/config.json
# Model weights saved in /content/checkpoint-36000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-35000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-36500
# Configuration saved in /content/checkpoint-36500/config.json
# Model weights saved in /content/checkpoint-36500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-35500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-37000
# Configuration saved in /content/checkpoint-37000/config.json
# Model weights saved in /content/checkpoint-37000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-36000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-37500
# Configuration saved in /content/checkpoint-37500/config.json
# Model weights saved in /content/checkpoint-37500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-36500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-38000
# Configuration saved in /content/checkpoint-38000/config.json
# Model weights saved in /content/checkpoint-38000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-37000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-38500
# Configuration saved in /content/checkpoint-38500/config.json
# Model weights saved in /content/checkpoint-38500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-37500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-39000
# Configuration saved in /content/checkpoint-39000/config.json
# Model weights saved in /content/checkpoint-39000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-38000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-39500
# Configuration saved in /content/checkpoint-39500/config.json
# Model weights saved in /content/checkpoint-39500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-38500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-40000
# Configuration saved in /content/checkpoint-40000/config.json
# Model weights saved in /content/checkpoint-40000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-39000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-40500
# Configuration saved in /content/checkpoint-40500/config.json
# Model weights saved in /content/checkpoint-40500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-39500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-41000
# Configuration saved in /content/checkpoint-41000/config.json
# Model weights saved in /content/checkpoint-41000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-40000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-41500
# Configuration saved in /content/checkpoint-41500/config.json
# Model weights saved in /content/checkpoint-41500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-40500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-42000
# Configuration saved in /content/checkpoint-42000/config.json
# Model weights saved in /content/checkpoint-42000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-41000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-42500
# Configuration saved in /content/checkpoint-42500/config.json
# Model weights saved in /content/checkpoint-42500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-41500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-43000
# Configuration saved in /content/checkpoint-43000/config.json
# Model weights saved in /content/checkpoint-43000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-42000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-43500
# Configuration saved in /content/checkpoint-43500/config.json
# Model weights saved in /content/checkpoint-43500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-42500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-44000
# Configuration saved in /content/checkpoint-44000/config.json
# Model weights saved in /content/checkpoint-44000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-43000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-44500
# Configuration saved in /content/checkpoint-44500/config.json
# Model weights saved in /content/checkpoint-44500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-43500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-45000
# Configuration saved in /content/checkpoint-45000/config.json
# Model weights saved in /content/checkpoint-45000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-44000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-45500
# Configuration saved in /content/checkpoint-45500/config.json
# Model weights saved in /content/checkpoint-45500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-44500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-46000
# Configuration saved in /content/checkpoint-46000/config.json
# Model weights saved in /content/checkpoint-46000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-45000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-46500
# Configuration saved in /content/checkpoint-46500/config.json
# Model weights saved in /content/checkpoint-46500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-45500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-47000
# Configuration saved in /content/checkpoint-47000/config.json
# Model weights saved in /content/checkpoint-47000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-46000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-47500
# Configuration saved in /content/checkpoint-47500/config.json
# Model weights saved in /content/checkpoint-47500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-46500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-48000
# Configuration saved in /content/checkpoint-48000/config.json
# Model weights saved in /content/checkpoint-48000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-47000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-48500
# Configuration saved in /content/checkpoint-48500/config.json
# Model weights saved in /content/checkpoint-48500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-47500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-49000
# Configuration saved in /content/checkpoint-49000/config.json
# Model weights saved in /content/checkpoint-49000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-48000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-49500
# Configuration saved in /content/checkpoint-49500/config.json
# Model weights saved in /content/checkpoint-49500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-48500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-50000
# Configuration saved in /content/checkpoint-50000/config.json
# Model weights saved in /content/checkpoint-50000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-49000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-50500
# Configuration saved in /content/checkpoint-50500/config.json
# Model weights saved in /content/checkpoint-50500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-49500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-51000
# Configuration saved in /content/checkpoint-51000/config.json
# Model weights saved in /content/checkpoint-51000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-50000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-51500
# Configuration saved in /content/checkpoint-51500/config.json
# Model weights saved in /content/checkpoint-51500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-50500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-52000
# Configuration saved in /content/checkpoint-52000/config.json
# Model weights saved in /content/checkpoint-52000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-51000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-52500
# Configuration saved in /content/checkpoint-52500/config.json
# Model weights saved in /content/checkpoint-52500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-51500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-53000
# Configuration saved in /content/checkpoint-53000/config.json
# Model weights saved in /content/checkpoint-53000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-52000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-53500
# Configuration saved in /content/checkpoint-53500/config.json
# Model weights saved in /content/checkpoint-53500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-52500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-54000
# Configuration saved in /content/checkpoint-54000/config.json
# Model weights saved in /content/checkpoint-54000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-53000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-54500
# Configuration saved in /content/checkpoint-54500/config.json
# Model weights saved in /content/checkpoint-54500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-53500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-55000
# Configuration saved in /content/checkpoint-55000/config.json
# Model weights saved in /content/checkpoint-55000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-54000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-55500
# Configuration saved in /content/checkpoint-55500/config.json
# Model weights saved in /content/checkpoint-55500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-54500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-56000
# Configuration saved in /content/checkpoint-56000/config.json
# Model weights saved in /content/checkpoint-56000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-55000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-56500
# Configuration saved in /content/checkpoint-56500/config.json
# Model weights saved in /content/checkpoint-56500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-55500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-57000
# Configuration saved in /content/checkpoint-57000/config.json
# Model weights saved in /content/checkpoint-57000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-56000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-57500
# Configuration saved in /content/checkpoint-57500/config.json
# Model weights saved in /content/checkpoint-57500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-56500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-58000
# Configuration saved in /content/checkpoint-58000/config.json
# Model weights saved in /content/checkpoint-58000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-57000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-58500
# Configuration saved in /content/checkpoint-58500/config.json
# Model weights saved in /content/checkpoint-58500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-57500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-59000
# Configuration saved in /content/checkpoint-59000/config.json
# Model weights saved in /content/checkpoint-59000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-58000] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-59500
# Configuration saved in /content/checkpoint-59500/config.json
# Model weights saved in /content/checkpoint-59500/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-58500] due to args.save_total_limit
# Saving model checkpoint to /content/checkpoint-60000
# Configuration saved in /content/checkpoint-60000/config.json
# Model weights saved in /content/checkpoint-60000/pytorch_model.bin
# Deleting older checkpoint [/content/checkpoint-59000] due to args.save_total_limit
